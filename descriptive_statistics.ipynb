# %%
import math
import math
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


print("******************************************************")
islem = input("istediğiniz betimsel istatistik işlemini giriniz:\n1-arimetik ortalama,\n2-geometrik ortalama,\n3-Harmonik Ortalama\n4-mod,\n5-medyan(Q2),\n6-standart sapma,\n7-varyans,\n8-min,\n9-max,\n10-ranj,\n11-Birinci Çeyreklik(Q1),\n12-Üçüncü Çeyreklik(Q3)\n13-Trimean (Tukey'in Üçlü Ortalaması)\n14-IQR-Çeyreklikler arası genişlik\n15-Aykırı değerler\n16-Genişletilmiş Medyan-Broadened Median (BMED) ")
print("******************************************************")

if islem == "1":
  veriler = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler.split()]
  toplam=sum(liste)
  n = len(liste)
  ort = (toplam/n)
  print(ort)
#*************************************************************************************#
elif islem == "2":
  veriler = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler.split()]
  carpım = math.prod(liste)
  n = len(liste)
  print(carpım**(1/n))
#*************************************************************************************#
elif islem == "3":
   veriler = input("Sayıları aralarında boşluk bırakarak giriniz: ")
   liste = [float(x) for x in veriler.split()]
   n = len(liste)
   toplam = sum(1/x for x in liste)
   print(n/toplam)

#*************************************************************************************#
elif islem == "4":
    veriler = input("Sayıları aralarında boşluk bırakarak giriniz: ")
    liste = [float(x) for x in veriler.split()]
    if not liste:
        print("Liste boş!")
    else:
        #En yüksek tekrar
        en_cok_tekrar = 0
        for x in liste:
            sayac = liste.count(x) # Her sayının kaç kez geçtiğini say
            if sayac > en_cok_tekrar:
                en_cok_tekrar = sayac
        modlar = []
        for x in liste:

            if liste.count(x) == en_cok_tekrar and x not in modlar:
                modlar.append(x)


        if en_cok_tekrar == 1 and len(liste) > 1:
            print("Mod yok (Her sayı birer kez geçmiş)")
        else:
            print(f"Mod: {modlar}, Tekrar sayısı: {en_cok_tekrar}")


#*************************************************************************************#

elif islem == "5":
    veriler = input("Sayıları aralarında boşluk bırakarak giriniz: ")
    liste = [float(x) for x in veriler.split()]

    liste.sort()
    n = len(liste) # Veri sayısı

    if n == 0:
        print("Liste boş!")
    else:
        # tek mi çift mi?
        if n % 2 == 1:
            # Tek ise
            medyan = liste[n // 2]
        else:
            # Çift ise
            orta1 = liste[n // 2 - 1]
            orta2 = liste[n // 2]
            medyan = (orta1 + orta2) / 2

        print(f"Sıralı Liste: {liste}")
        print(f"Medyan (Ortanca): {medyan}")
#*************************************************************************************#
elif islem == "6":
  veriler = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler.split()]
  toplam=sum(liste)
  n = len(liste)
  ort = (toplam/n)
  kare_farklar_toplami = sum([(x - ort)**2 for x in liste])
  varyans = kare_farklar_toplami / (n - 1) # Örneklem standart sapması için n-1
  standart_sapma = varyans ** 0.5 # Karekök alıyoruz
  print(f"Standart Sapma: {standart_sapma}")
#*************************************************************************************#
elif islem == "7":
  veriler = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler.split()]
  toplam=sum(liste)
  n = len(liste)
  ort = (toplam/n)
  kare_farklar_toplami = sum([(x - ort)**2 for x in liste])
  varyans = kare_farklar_toplami / (n - 1) # Örneklem standart sapması için n-1
  standart_sapma = varyans ** 0.5 # Karekök alıyoruz
  print(f"Varyans: {varyans}")
#*************************************************************************************#
elif islem == "8":
  veriler = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler.split()]
  print(min(liste))
#*************************************************************************************#
elif islem == "9":
  veriler = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler.split()]
  print(max(liste))
#*************************************************************************************#
elif islem =="10":
  veriler = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler.split()]
  print(max(liste)- min(liste))
#*************************************************************************************#
elif islem == "11":
  veriler_str = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler_str.split()]

  liste.sort()
  n = len(liste) # Veri sayısı

  if n == 0:
        print("Liste boş!")
  else:
        # tek mi çift mi?
        if n % 2 == 1:
            # Tek ise
            medyan = liste[n // 2]
        else:
            # Çift ise
            orta1 = liste[n // 2 - 1]
            orta2 = liste[n // 2]
            medyan = (orta1 + orta2) / 2

        print(f"Medyan (Ortanca): {medyan}")

        kucuk_olanlar = [x for x in liste if x < medyan]
        kucuk_olanlar.sort()
        n2 = len(kucuk_olanlar)
        if n2 == 0:
          print("Liste boş!")
        else:
        # tek mi çift mi?
          if n2 % 2 == 1:
            # Tek ise
            Q1 = liste[n2 // 2]
          else:
            # Çift ise
            Q1_orta1 = liste[n2 // 2 - 1]
            Q1_orta2 = liste[n2 // 2]
            Q1 = (Q1_orta1 + Q1_orta2) / 2
        print(f"Q1: {Q1}")
#*************************************************************************************#
elif islem == "12":
  veriler_str2 = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler_str2.split()]

  liste.sort()
  n = len(liste) # Veri sayısı

  if n == 0:
        print("Liste boş!")
  else:
        # tek mi çift mi?
        if n % 2 == 1:
            # Tek ise
            medyan2 = liste[n // 2]
        else:
            # Çift ise
            orta1 = liste[n // 2 - 1]
            orta2 = liste[n // 2]
            medyan2 = (orta1 + orta2) / 2

        print(f"Medyan (Ortanca): {medyan2}")

        buyuk_olanlar = [x for x in liste if x > medyan2]
        buyuk_olanlar.sort()
        n3 = len(buyuk_olanlar)
        if n3 == 0:
          print("Liste boş!")
        else:
        # tek mi çift mi?
          if n3 % 2 == 1:
            # Tek ise
            Q3 = buyuk_olanlar[n3 // 2]
          else:
            # Çift ise
            Q3_orta1 = buyuk_olanlar[n3 // 2 - 1]
            Q3_orta2 = buyuk_olanlar[n3 // 2]
            Q3 = (Q3_orta1 + Q3_orta2) / 2
        print(f"Q3: {Q3}")
#*************************************************************************************#
elif islem == "13":
  veriler_str3 = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler_str3.split()]

  liste.sort()
  n = len(liste) # Veri sayısı

  if n == 0:
        print("Liste boş!")
  else:
        # tek mi çift mi?
        if n % 2 == 1:
            # Tek ise
            medyan = liste[n // 2]
        else:
            # Çift ise
            orta1 = liste[n // 2 - 1]
            orta2 = liste[n // 2]
            medyan = (orta1 + orta2) / 2

        print(f"Medyan (Ortanca): {medyan}")
        kucuk_olanlar = [x for x in liste if x < medyan]
        kucuk_olanlar.sort()
        n2 = len(kucuk_olanlar)
        if n2 == 0:
          print("Liste boş!")
        else:
        # tek mi çift mi?
          if n2 % 2 == 1:
            # Tek ise
            Q1 = liste[n2 // 2]
          else:
            # Çift ise
            Q1_orta1 = liste[n2 // 2 - 1]
            Q1_orta2 = liste[n2 // 2]
            Q1 = (Q1_orta1 + Q1_orta2) / 2
        print(f"Q1: {Q1}")
        buyuk_olanlar = [x for x in liste if x > medyan]
        buyuk_olanlar.sort()
        n3 = len(buyuk_olanlar)
        if n3 == 0:
          print("Liste boş!")
        else:
        # tek mi çift mi?
          if n3 % 2 == 1:
            # Tek ise
            Q3 = buyuk_olanlar[n3 // 2]
          else:
            # Çift ise
            Q3_orta1 = buyuk_olanlar[n3 // 2 - 1]
            Q3_orta2 = buyuk_olanlar[n3 // 2]
            Q3 = (Q3_orta1 + Q3_orta2) / 2
        print(f"Q3: {Q3}")

  print(f"TRIMEAN: {(1/4)*(Q1 + 2*medyan + Q3)}")
#*************************************************************************************#
elif islem == "14":
  veriler_str3 = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler_str3.split()]
  liste.sort()
  n = len(liste) # Veri sayısı

  if n == 0:
        print("Liste boş!")
  else:
        # tek mi çift mi?
        if n % 2 == 1:
            # Tek ise
            medyan = liste[n // 2]
        else:
            # Çift ise
            orta1 = liste[n // 2 - 1]
            orta2 = liste[n // 2]
            medyan = (orta1 + orta2) / 2

        print(f"Medyan (Ortanca): {medyan}")
        kucuk_olanlar = [x for x in liste if x < medyan]
        kucuk_olanlar.sort()
        n2 = len(kucuk_olanlar)
        if n2 == 0:
          print("Liste boş!")
        else:
        # tek mi çift mi?
          if n2 % 2 == 1:
            # Tek ise
            Q1 = liste[n2 // 2]
          else:
            # Çift ise
            Q1_orta1 = liste[n2 // 2 - 1]
            Q1_orta2 = liste[n2 // 2]
            Q1 = (Q1_orta1 + Q1_orta2) / 2
        print(f"Q1: {Q1}")
        buyuk_olanlar = [x for x in liste if x > medyan]
        buyuk_olanlar.sort()
        n3 = len(buyuk_olanlar)
        if n3 == 0:
          print("Liste boş!")
        else:
        # tek mi çift mi?
          if n3 % 2 == 1:
            # Tek ise
            Q3 = buyuk_olanlar[n3 // 2]
          else:
            # Çift ise
            Q3_orta1 = buyuk_olanlar[n3 // 2 - 1]
            Q3_orta2 = buyuk_olanlar[n3 // 2]
            Q3 = (Q3_orta1 + Q3_orta2) / 2
        print(f"Q3: {Q3}")
        df = Q3-Q1
        print(f"IQR (Çeyrekler Arası Genişlik): {df}")
#*************************************************************************************#

elif islem == "15":
  veriler_str3 = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler_str3.split()]
  liste.sort()
  n = len(liste) # Veri sayısı

  if n == 0:
        print("Liste boş!")
  else:
        # tek mi çift mi?
        if n % 2 == 1:
            # Tek ise
            medyan = liste[n // 2]
        else:
            # Çift ise
            orta1 = liste[n // 2 - 1]
            orta2 = liste[n // 2]
            medyan = (orta1 + orta2) / 2

        print(f"Medyan (Ortanca): {medyan}")
        kucuk_olanlar = [x for x in liste if x < medyan]
        kucuk_olanlar.sort()
        n2 = len(kucuk_olanlar)
        if n2 == 0:
          print("Liste boş!")
        else:
        # tek mi çift mi?
          if n2 % 2 == 1:
            # Tek ise
            Q1 = liste[n2 // 2]
          else:
            # Çift ise
            Q1_orta1 = liste[n2 // 2 - 1]
            Q1_orta2 = liste[n2 // 2]
            Q1 = (Q1_orta1 + Q1_orta2) / 2
        print(f"Q1: {Q1}")
        buyuk_olanlar = [x for x in liste if x > medyan]
        buyuk_olanlar.sort()
        n3 = len(buyuk_olanlar)
        if n3 == 0:
          print("Liste boş!")
        else:
        # tek mi çift mi?
          if n3 % 2 == 1:
            # Tek ise
            Q3 = buyuk_olanlar[n3 // 2]
          else:
            # Çift ise
            Q3_orta1 = buyuk_olanlar[n3 // 2 - 1]
            Q3_orta2 = buyuk_olanlar[n3 // 2]
            Q3 = (Q3_orta1 + Q3_orta2) / 2
        print(f"Q3: {Q3}")
        df = Q3-Q1
        print(f"IQR (Çeyrekler Arası Genişlik): {df}")
        cl = Q1 - (1.5*df)
        cu = Q3 + (1.5*df)
        print(f"hafif şiddetli alt eşik değeri: {cl}")
        print(f"hafif şiddetli üst eşik değeri: {cu}")

        altaykırılar = [x for x in liste if x < cl]
        ustaykırılar = [x for x in liste if x > cu]
        print(f"alt aykırı değerler: {altaykırılar}")
        print(f"üst aykırı değerler: {ustaykırılar}")

        plt.figure(figsize=(8, 6))
        plt.boxplot(liste, vert=False, patch_artist=True, boxprops=dict(facecolor="lightblue"))
        plt.title("Veri Setinin Kutu Grafiği")
        plt.xlabel("Değerler")
        plt.show()
#*************************************************************************************#
elif islem == "16":
  veriler = input("Sayıları aralarında boşluk bırakarak giriniz: ")
  liste = [float(x) for x in veriler.split()]

  def broadened_median(liste):
    x = np.sort(liste) #sayıları sırala
    n = len(x) #n
    if n < 5: #normal median hesabı yapılır
        if n == 0:
         print("Liste boş!")
    else:
        # tek mi çift mi?
        if n % 2 == 1:
            # Tek ise
            medyan = liste[n // 2]
        else:
            # Çift ise
            orta1 = liste[n // 2 - 1]
            orta2 = liste[n // 2]
            medyan = (orta1 + orta2) / 2


    if n % 2 != 0: # n tek ise
        k = (n + 1) // 2 - 1 # 0-tabanlı indeksleme
        if 5 <= n <=12:
          return np.mean(x[k-1 : k+2]) #ortadaki 3 sıra ist. aritmetik ortalaması
        else: #n>=13
            return np.mean(x[k-2:k+3]) #ortadaki 5 sıra ist. aritmetik ortalaması

    else: # n çift ise
        k = n // 2 - 1
        if 5 <=n <=12:
          return (1/6)*x[k-1] + (1/3)*x[k] + (1/3)*x[k+1] + (1/6)*x[k+2]  #ortadaki 4 sıra ist. ağırlıklı ortalaması
        else: #n>=13
          return (1/10)*x[k-2] + (1/5)*x[k-1] + (1/5)*x[k] + (1/5)*x[k+1] + (1/5)*x[k+2] + (1/10)*x[k+3]  #ortadaki 6 sıra ist. ağırlıklı ortalaması

  hesaplanan_deger = broadened_median(liste)
  print(f"BMED: {hesaplanan_deger}")




#*************************************************************************************#
else:
  print("işlem yok")
# Out:
# ******************************************************
# istediğiniz betimsel istatistik işlemini giriniz:
# 1-arimetik ortalama,
# 2-geometrik ortalama,
# 3-Harmonik Ortalama
# 4-mod,
# 5-medyan(Q2),
# 6-standart sapma,
# 7-varyans,
# 8-min,
# 9-max,
# 10-ranj,
# 11-Birinci Çeyreklik(Q1),
# 12-Üçüncü Çeyreklik(Q3)
# 13-Trimean (Tukey'in Üçlü Ortalaması)
# 14-IQR-Çeyreklikler arası genişlik
# 15-Aykırı değerler
# 16-Genişletilmiş Medyan-Broadened Median (BMED) 1
# ******************************************************
# Sayıları aralarında boşluk bırakarak giriniz: 1230022
# 1230022.0
